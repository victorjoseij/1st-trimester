# %% [markdown]
# <a href="https://colab.research.google.com/github/victorjoseij/1st-trimester/blob/main/2348570_EX1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/data - data.csv')

# %%
df.head()
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 0:00   313000.0         3       1.50         1340      7912
# 1  02-05-2014 0:00  2384000.0         5       2.50         3650      9050
# 2  02-05-2014 0:00   342000.0         3       2.00         1930     11947
# 3  02-05-2014 0:00   420000.0         3       2.25         2000      8030
# 4  02-05-2014 0:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.head()
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 0:00   313000.0         3       1.50         1340      7912
# 1  02-05-2014 0:00  2384000.0         5       2.50         3650      9050
# 2  02-05-2014 0:00   342000.0         3       2.00         1930     11947
# 3  02-05-2014 0:00   420000.0         3       2.25         2000      8030
# 4  02-05-2014 0:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
summary_stats = df.describe()
print("Summary Statistics:\n", summary_stats)
# Out:
# Summary Statistics:
#                price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# ...

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='sunrise', fmt=".2f", square=True)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-9-74422a1c49fb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-74422a1c49fb> in <cell line: 3>()
#       1 correlation_matrix = df.corr()
#       2 plt.figure(figsize=(12, 10))
# ----> 3 sns.heatmap(correlation_matrix, annot=True, cmap='sunrise', fmt=".2f", square=True)
#       4 plt.title('Correlation Heatmap')
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
# ...
